# %%
import os
os.chdir('../')

import stravaviz.interactive_heatmap as interactive_heatmap

# %% [markdown]
# Github preview doesn't render interactive plots. To view the plots, download and run the notebook or [view the plots on nbviewer](https://nbviewer.jupyter.org/github/ashleyshine/stravaviz/blob/master/notebooks/interactive_heatmaps.ipynb).

# %%
# Create a heatmap by passing in coordinates to center the map on
# and parameters for the activities to be plotted (optional)

# Default style is a dark heatmap with blue polylines
interactive_heatmap.create_heatmap(
    center=[34.063361, -118.440161],
    activities={'after': '2016-01-01', 'before': '2018-09-01'},
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Customize heatmap by using style and color arguments
# Heatmap styles include 'dark' and 'light'

interactive_heatmap.create_heatmap(
    center=[34.063361, -118.440161],
    activities={'after': '2018-06-15', 'before': '2018-09-01'},
    style='light',
    color='orangered'
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
