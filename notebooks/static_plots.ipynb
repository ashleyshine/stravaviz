# %%
import os
os.chdir('../')

import stravaviz.plots as plots

# %% [markdown]
# # Heatmaps

# %% [markdown]
# ### Visualizing a Summer of Running

# %%
# Default heatmap style is dark with blue polylines
plots.create_heatmap(activities={'after': '2018-06-01', 'before': '2018-09-01'})

# %% [markdown]
# ### The life of a UCLA runner: running UCLA's perimeter over and over again

# %%
# Create heatmaps with custom colors using style and color arguments
plots.create_heatmap(
    activities={'after': '2018-01-15', 'before': '2018-06-01'},
    style='white',
    color='black'
)

# %% [markdown]
# # Facet Plots
#
# ### Seriously, I'm all about that perimeter life...

# %%
# Default facet plot style is white with black polylines
plots.create_facet_plot(activities={'after': '2015-09-01', 'before': '2018-09-21'})

# %% [markdown]
# ### Mixing it up with some rectangles this summer

# %%
# Customize facet plot using style and color arguments
plots.create_facet_plot(
    activities={'after': '2018-06-01', 'before': '2018-09-21'},
    style='black',
    color='orangered'
)
